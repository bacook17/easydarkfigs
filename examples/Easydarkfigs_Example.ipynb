# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import easydarkfigs
# %matplotlib inline

# %% [markdown]
# The examples below show you how to use the `easydarkfigs` magic calls

# %%
x = np.linspace(0, 10, 500)
y = np.cos(x)
z = np.cos(x+1.)
zerr = np.random.uniform(low=0, high=0.5, size=(len(z)))

# %% [markdown]
# # Setup

# %% [markdown]
# ## Figure Appendix and Save Directories
#
# First, you can check the appendix that will be added to dark figures, and the directories the light/dark figures will be saved to

# %%
# %get_darkappend
# Out:
# '_dark'

# %%
# %get_lightfigdir
# Out:
# ''

# %%
# %get_darkfigdir
# Out:
# ''

# %% [markdown]
# If you want to change them, it's as simple as:

# %%
# %set_lightfigdir figures/

# %%
# %get_lightfigdir
# Out:
# 'figures/'

# %% [markdown]
# ## Light and Dark Styles

# %% [markdown]
# Let's also check we're happy with the default light and dark styles

# %%
# %get_lightstyle
# Out:
# 'easy-light'

# %%
print(plt.style.library['easy-light'])
# Out:
# axes.edgecolor: k
# axes.facecolor: w
# axes.labelcolor: k
# axes.labelsize: 14.0
# axes.prop_cycle: (cycler('linestyle', ['-', '--', ':', '-.']) * cycler('color', ['#0072b2', '#009e73', '#d55e00', '#cc79a7', '#f0e442', '#56b4e9', '#0072b2', '#009e73', '#d55e00', '#cc79a7']))
# axes.titlesize: 16.0
# figure.edgecolor: w
# figure.facecolor: w
# figure.figsize: [12.8, 8.8]
# grid.color: k
# grid.linewidth: 1.6
# image.origin: lower
# legend.fontsize: 14.0
# lines.color: k
# lines.linewidth: 2.0
# lines.markeredgewidth: 2.0
# lines.markersize: 12.0
# patch.edgecolor: k
# patch.linewidth: 2.0
# savefig.bbox: tight
# savefig.edgecolor: w
# savefig.facecolor: w
# savefig.format: pdf
# savefig.pad_inches: 0.1
# text.color: k
# xtick.color: k
# xtick.labelsize: 10.0
# xtick.major.pad: 8.0
# xtick.major.width: 1.6
# xtick.minor.width: 0.8
# ytick.color: k
# ytick.labelsize: 10.0
# ytick.major.pad: 8.0
# ytick.major.width: 1.6
# ytick.minor.width: 0.8

# %%
with plt.style.context(('easy-light')):
    plt.plot([0, 1], label='Line')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Title')
    plt.legend(loc=0)

# %%
# %get_darkstyle
# Out:
# 'easy-dark'

# %%
print(plt.style.library['easy-dark'])
# Out:
# axes.edgecolor: w
# axes.facecolor: k
# axes.labelcolor: w
# axes.labelsize: 14.0
# axes.prop_cycle: (cycler('linestyle', ['-', '--', ':', '-.']) * cycler('color', ['#0072b2', '#009e73', '#d55e00', '#cc79a7', '#f0e442', '#56b4e9', '#0072b2', '#009e73', '#d55e00', '#cc79a7']))
# axes.titlesize: 16.0
# figure.edgecolor: k
# figure.facecolor: k
# figure.figsize: [12.8, 8.8]
# grid.color: w
# grid.linewidth: 1.6
# image.origin: lower
# legend.fontsize: 14.0
# lines.color: w
# lines.linewidth: 2.0
# lines.markeredgewidth: 2.0
# lines.markersize: 12.0
# patch.edgecolor: w
# patch.linewidth: 2.0
# savefig.bbox: tight
# savefig.edgecolor: k
# savefig.facecolor: k
# savefig.format: pdf
# savefig.pad_inches: 0.1
# text.color: w
# xtick.color: w
# xtick.labelsize: 10.0
# xtick.major.pad: 8.0
# xtick.major.width: 1.6
# xtick.minor.width: 0.8
# ytick.color: w
# ytick.labelsize: 10.0
# ytick.major.pad: 8.0
# ytick.major.width: 1.6
# ytick.minor.width: 0.8

# %%
with plt.style.context(('easy-dark')):
    plt.plot([0, 1], label='Line')
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title('Title')
    plt.legend(loc=0)

# %% [markdown]
# If you want to change the styles that will be used to plot the light/dark figures:

# %%
# %set_lightstyle other-dark-style

# %%
# %get_lightstyle
# Out:
# 'other-dark-style'

# %%
# Set it back for demo
# %set_lightstyle easy-light

# %% [markdown]
# # Usage

# %% [markdown]
# You've just spent all day making this gorgeous plot in your Jupyter notebook. Often we want to save it in two forms:
#
# * Light-background version (for papers)
#
# * Dark-background version (for presentations)
#
# To do so, just wrap your Jupyter cell in the included iPython magic function `savefig_dark_light`, and give it a file name

# %%
# %%savefig_dark_light test_fig.jpg
# fig, ax = plt.subplots()
# ax.plot(x, y)
# ax.errorbar(x, y=z, yerr=zerr)
# ax.set_xlabel('Time')
# ax.set_ylabel('Awesomeness');
# Out:
# Saving light figure as figures/test_fig.jpg
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-9f65e8666d9f> in <module>()
# ----> 1 get_ipython().run_cell_magic('savefig_dark_light', 'test_fig.jpg', "fig, ax = plt.subplots()\nax.plot(x, y)\nax.errorbar(x, y=z, yerr=zerr)\nax.set_xlabel('Time')\nax.set_ylabel('Awesomeness');")
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2129             magic_arg_s = self.var_expand(line, stack_depth)
#    2130             with self.builtin_trap:
# -> 2131                 result = fn(magic_arg_s, cell)
#    2132             return result
#    2133
#
# <decorator-gen-135> in savefig_dark_light(self, line, cell)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/easydarkfigs/figuremagic.py in savefig_dark_light(self, line, cell)
#      86             self.shell.ex(cell)
#      87             stderr.write('Saving light figure as %s\n' % (light_figname))
# ---> 88             plt.savefig(light_figname)
#      89         with plt.style.context((self.darkstyle)):
#      90             self.shell.ex(cell)
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, *args, **kwargs)
#     576                 options['dpi'] = (options['dpi'], options['dpi'])
#     577
# --> 578             return background.save(filename_or_obj, format='jpeg', **options)
#     579         print_jpeg = print_jpg
#     580
#
# ~/anaconda/envs/py36/lib/python3.6/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1925             # Open also for reading ("+"), because TIFF save_all
#    1926             # writer needs to go back and edit the written data.
# -> 1927             fp = builtins.open(filename, "w+b")
#    1928
#    1929         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figures/test_fig.jpg'

# %%
# !ls figures/*.jpg

# %%
# !ls *.jpg
